# %% [markdown]
# تشخیص اب و هوای ثانیه ای یک مکان

# %%
import requests, json



api_key = "4c1cc4dbe03dcf2f1c3dafe2cf2c8928"
 
base_url = "http://api.openweathermap.org/data/2.5/weather?"
 
city_name = input("Enter city name : ")

complete_url = base_url + "appid=" + api_key + "&q=" + city_name + "&units=metric"

print(complete_url)

response = requests.get(complete_url)

x = response.json()

x['main']['temp']
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=4c1cc4dbe03dcf2f1c3dafe2cf2c8928&q=tehran&units=metric
# 29.84
